# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# # 1. Overview
#
# #### Data
#
# The data folder contains:
#
# input data:
# - "train.csv" (Download from: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data)
#
#
# exported status csv for further analysis:
# - cleandata.csv
# - corrdf.csv
#
# #### Subs
#
# The subs folder contains all notebooks with stept of current analysis status.
#
#          - sub1: Step 1 - Data Cleaning
#          - sub2: Step 2 - Correlations
#          - sub3: Step 3 - Time Dependency
#          - sub4: Step 4 - OLS
#
#
#
# #### Status
#
# status of analysis: 13-09-2020

# %% [markdown]
# # 2. Summary
#
# ### Please find detailed analysis in each sub notebook
#
# #### Only major steps, collected from all subs, will be summarized here

# %% [markdown]
# ### Step 1

# %%
##############################################################################
#####################################################################
#####################################################################
#
# DATA CLEANING: 
#                 null-values and object dtypes
#
#####################################################################
##############################################################################

# %%
####################################################################################################################
####################################################################################################################
### EXPORT:
#
# cleandf to csv

# cleandf.to_csv('cleandata.csv')

####################################################################################################################
####################################################################################################################

# %% [markdown]
# ### Step 2

# %%
##############################################################################
#####################################################################
#####################################################################
#
# STEP 2 - CORRELATIONS: 
#
#               correlations all columns ⇔ sold-houses prices
#
#####################################################################
##############################################################################

# %%
from IPython.display import Image
Image(filename= 'g1.png')

# %%
###############################################################################
#### NOTES:
#
# boxplot shows cols with highest 'price' correlations:
#
#     - 1. RANK: 'OveralQual' 
#     - 2. RANK: 'GrLivArea'
#     - 3. RANK: 'GarageCars'
#     - 4. RANK: 'GarageArea'
#     - 5. RANK: 'TotalBsmtSF'
#
###############################################################################

# %% [markdown]
# ## Step 3

# %%
##############################################################################
#####################################################################
#####################################################################
#
# STEP 3 - DATE DEPENDENCY:
#
#                year and month ⇔ sold-houses prices
#
#####################################################################
##############################################################################

# %%
##############################################################################
##############################################################################
#
# STEP 3-1: OVERVIEW 
#
#         DATE-PRICE ALL VALUES
#
###################################################
###################################################

# %%
###############################################################################
#### NOTES: 
#
# impressionist plot shows: 
#     - density (= number of houses sold): varies over time: peaks in summers     
#     - price range: most houses between 10K and 30K, 
#                    only a handful prices >10K or >30K
#     - relation: prices also seem to increase during selling-season(=summer) 
#
###############################################################################

# %%
# impressionist plot:

from IPython.display import Image
Image(filename= 'g2.png')

# %%
##############################################################################
##############################################################################
#
# STEP 3-2: YEARLY SALES 
#                       - PRICES
#                       
###################################################
###################################################

# %%
##############################################################################
##############################################################################
#
# STEP 3-3: MONTHLY SALES
#                        - PRICES
# 
###################################################
###################################################

# %%
###############################################################################
#
# TIME PLOT:

from IPython.display import Image
Image(filename= 'g3.png')

# %%
###############################################################################
###############################################################################
#### NOTES: 
#
# plot shows: 
#     - assumed dependency price-month is encouraged
#     - peaks in summer-months
#
###############################################################################

# %%
##############################################################################
#####################################################################
#####################################################################
#
# OLS: 
#     all columns ⇔ sold-houses prices
#
#####################################################################
##############################################################################

# %%
# OLS: all columns

from IPython.display import Image
Image(filename= 'g4.png')

# %%
# OLS: Top1 OverallQual

from IPython.display import Image
Image(filename= 'g5.png')

# %%
# OLS: Top2 GrLivArea 

from IPython.display import Image
Image(filename= 'g6.png')

# %%
# OLS: Top3 GarageCars

from IPython.display import Image
Image(filename= 'g7.png')

# %%
# OLS: crosscheck month

from IPython.display import Image
Image(filename= 'g9.png')

# %%
##################################################################################
##################################################################################
### NOTES:
#
#       R-squared:
#                  - month:        0.002
#
#                  - GarageCars:   0.410
#                  - GrLivArea:    0.507
#                  - OverallQual:  0.614
#
#
##################################################################################
##################################################################################
