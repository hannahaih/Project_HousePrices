# %%
##############################################################################
#####################################################################
#####################################################################
#
# DATA CLEANING: 
#                 null-values and object dtypes
#
#####################################################################
##############################################################################

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from numpy import arange
import math

import seaborn as sns
sns.set_style("white")

import scipy as sp
from scipy import linalg, optimize

import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

import collections
from collections import Counter

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.path as mpath
from matplotlib.dates import DateFormatter

import calendar
import datetime as dt
fromtimestamp = dt.datetime.fromtimestamp

 # importing raw input data
raw = pd.read_csv("../data/train.csv")
    # confirm
raw.head(1)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
#
# [1 rows x 81 columns]

# %%
# safety-first:

    # copy df into w(orking)df:
wdf = raw.copy()
    # make sure vals in col"id" are all unique:
len(wdf['Id'].unique())==len(wdf)
# Out:
# True

# %%
# add date col:

wdf = wdf.assign(date=wdf['MoSold'].astype(str)+"-"+wdf['YrSold'].astype(str))
    # translate to datetime + update df 
wdf['date'] = pd.to_datetime(wdf.date)
        # rename important cols with short and easy names + sort by date, price
wdf = wdf.rename(columns={'Id':'id','SalePrice':'price', 'YrSold':'year', 'MoSold':'month'}).sort_values(['date','price'])

# %%
# add constant:

wdf = sm.add_constant(wdf)

# %% [markdown]
# # NA Values

# %%
# null values:

    # storing 50% len of raw df 
halfdf = len(raw)/2

    # new df for count of na-vals
nasumdf = pd.DataFrame(wdf.isna().sum())
nasumdf = nasumdf.reset_index().rename(columns={'index': 'col',0:'sum_of_na'}).sort_values('col')
nasumdf = nasumdf.loc[nasumdf['sum_of_na']>0].reset_index()
    
    # new df for all cols with > 50% na
naover50 = nasumdf.loc[nasumdf['sum_of_na']>halfdf]
    # review:
naover50
# Out:
#     index          col  sum_of_na
# 0       7        Alley       1369
# 7      74        Fence       1179
# 17     75  MiscFeature       1406
# 18     73       PoolQC       1453

# %%
    # new df to store col with > 25% na vals
naover25 = nasumdf.loc[nasumdf['sum_of_na']>halfdf/2]
    #review
naover25
# Out:
#     index          col  sum_of_na
# 0       7        Alley       1369
# 7      74        Fence       1179
# 8      58  FireplaceQu        690
# 17     75  MiscFeature       1406
# 18     73       PoolQC       1453

# %%
##############################################################################
###  NA HANDELING:
#
# ⟹ observation: 4 cols contain over 50% na vals, 1 over 25%
#    ⟹ conclusion: info value not not sufficient for further analysis 
#    ⟹ decision: drop cols Alley, Fence, MiscFeature, PoolQC
# ⟹ observation: 14 more cols need further investigation
#    ⟹ next step: cols saved in 'investigate' value inspection
#
##############################################################################

    # saving cols to drop in list
colstodrop = naover25['col'].to_list()

    # drop and update wdf
wdf = wdf.drop(columns=[c for c in colstodrop])

# %%
nasumdf2 = pd.DataFrame(wdf.isna().sum()).reset_index().rename(columns={'index':'col',0:'nas'}).sort_values('nas',ascending=False)
nasumdf2 = nasumdf2.loc[nasumdf2['nas']>0]
    # review
nasumdf2
        # observation: 14 cols still have na vals
            # decision: drop rows containing na, if these rows make <= 5.5% of len(raw)
# Out:
#              col  nas
# 4    LotFrontage  259
# 58   GarageYrBlt   81
# 63    GarageCond   81
# 57    GarageType   81
# 59  GarageFinish   81
# 62    GarageQual   81
# 35  BsmtFinType2   38
# 32  BsmtExposure   38
# 33  BsmtFinType1   37
# 31      BsmtCond   37
# 30      BsmtQual   37
# 26    MasVnrArea    8
# 25    MasVnrType    8
# 42    Electrical    1

# %%
    # storing %5.5 of len(raw) in fivepc
fivepc = (len(raw)/100)*5.5

# %%
    # save 5.5% na in df
fivepcdf = nasumdf2.loc[nasumdf2['nas']<fivepc]
    # storing cols with < 5% na vals in list:
colfivepc = fivepcdf['col'].to_list()
    # review: 
# out=
colfivepc = ['BsmtFinType2', 'BsmtExposure', 'BsmtFinType1', 'BsmtCond', 'BsmtQual', 'MasVnrArea', 'MasVnrType', 'Electrical', 'GarageYrBlt','GarageFinish', 'GarageQual', 'GarageCond', 'GarageType']

# %%
# drop fivepc rows and update wdf:
for col in colfivepc:
    l = wdf.loc[wdf[col].isna()].index.to_list()
    wdf = wdf.drop(l)

# %%
# review remaining na sums
nasumdf3 = wdf.isna().sum().reset_index().rename(columns={'index':'col',0:'nas'}).sort_values('nas',ascending=False)
nasumdf3 = nasumdf3.loc[nasumdf3['nas']>0]
nasumdf3['col'].to_list()

    # observation: only one col remains : LotFrontage
# Out:
# ['LotFrontage']

# %%
    # closer look at col LotFrontage
wdf['LotFrontage'].value_counts()
# Out:
# 60.0     120
# 80.0      67
# 70.0      63
# 75.0      50
# 50.0      49
#         ...
# 150.0      1
# 144.0      1
# 160.0      1
# 46.0       1
# 141.0      1
# Name: LotFrontage, Length: 107, dtype: int64

# %%
wdf['LotFrontage'].min()
# Out:
# 21.0

# %%
wdf['LotFrontage'].max()
# Out:
# 313.0

# %%
wdf['LotFrontage'].mean()
# Out:
# 70.75959780621572

# %%
wdf['LotFrontage'].median()
# Out:
# 70.0

# %%
wdf['LotFrontage'].std()
# Out:
# 24.508858570320566

# %%
    # review concerned rows
wdf.loc[wdf['LotFrontage'].isna()]
# Out:
#       const    id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 996     1.0   997          20       RL          NaN    10659   Pave      IR1
# 370     1.0   371          60       RL          NaN     8121   Pave      IR1
# 169     1.0   170          20       RL          NaN    16669   Pave      IR1
# 545     1.0   546          50       RL          NaN    13837   Pave      IR1
# 1033    1.0  1034          20       RL          NaN     8125   Pave      Reg
# ...     ...   ...         ...      ...          ...      ...    ...      ...
# 1358    1.0  1359         160       FV          NaN     2117   Pave      Reg
# 470     1.0   471         120       RL          NaN     6820   Pave      IR1
# 412     1.0   413          20       FV          NaN     4403   Pave      IR2
# 939     1.0   940          70       RL          NaN    24090   Pave      Reg
# 66      1.0    67          20       RL          NaN    19900   Pave      Reg
#
#      LandContour Utilities  ... 3SsnPorch ScreenPorch PoolArea MiscVal month  \
# 996          Lvl    AllPub  ...         0           0        0       0     1
# 370          Lvl    AllPub  ...         0           0        0       0     1
# 169          Lvl    AllPub  ...         0           0        0       0     1
# 545          Lvl    AllPub  ...         0           0        0       0     2
# 1033         Lvl    AllPub  ...         0           0        0       0     2
# ...          ...       ...  ...       ...         ...      ...     ...   ...
# 1358         Lvl    AllPub  ...         0           0        0       0     6
# 470          Lvl    AllPub  ...         0         140        0       0     6
# 412          Lvl    AllPub  ...         0           0        0       0     6
# 939          Lvl    AllPub  ...         0           0        0       0     6
# 66           Lvl    AllPub  ...         0           0        0       0     7
#
#       year SaleType  SaleCondition   price       date
# 996   2006      COD         Normal  136500 2006-01-01
# 370   2006       WD         Normal  172400 2006-01-01
# 169   2006       WD         Normal  228000 2006-01-01
# 545   2006       WD         Normal  229000 2006-02-01
# 1033  2006       WD         Normal  230000 2006-02-01
# ...    ...      ...            ...     ...        ...
# 1358  2010       WD         Normal  177500 2010-06-01
# 470   2010       WD         Normal  212000 2010-06-01
# 412   2010      New        Partial  222000 2010-06-01
# 939   2010      COD         Normal  244400 2010-06-01
# 66    2010       WD         Normal  180000 2010-07-01
#
# [244 rows x 78 columns]

# %%
###################################################################################################################
### NOTES:
#
# observation: col 'LotArea' has values where 'LotFrontage' is na
    # decision: try to figure out if there is some correlation between these two
###################################################################################################################

    # get these cols and save them to lotdf:
    
lotdf = wdf.copy()
lotdf = lotdf.get(['LotFrontage','LotArea']).dropna().sort_values('LotArea')

# %%
###################################################################################################################
### NOTES:
# 
# consideration:
#        if all lots would be squares, the lenght the frontages would be square-roots of each areas
# 
# conclusion:
#        assign a col with frontage-lenghts if areas were squares to review deviations
###################################################################################################################

# %%
    # assign col with lenght if area is suare
lotdf = lotdf.assign(ifsqare= np.sqrt(lotdf['LotArea']))

    # assign col with difference beween real frontage and squarefrontage
lotdf = lotdf.assign(diff=lotdf['ifsqare'] - lotdf['LotFrontage']).sort_values('diff')

# review key values of difference:

# %%
lotdf['diff'].std()
# Out:
# 22.437757978655192

# %%
lotdf['diff'].max()
# Out:
# 313.9450398484717

# %%
lotdf['diff'].min()
# Out:
# -146.7171085168411

# %%
lotdf['diff'].mean()
# Out:
# 26.634305902799504

# %%
lotdf['diff'].median()
# Out:
# 24.810547537889594

# %%
# closer look at highest diff
lotdf.tail(10)
# Out:
#       LotFrontage  LotArea     ifsqare        diff
# 1409         46.0    20544  143.331783   97.331783
# 692          42.0    26178  161.796168  119.796168
# 271          73.0    39104  197.747314  124.747314
# 1184         50.0    35133  187.437990  137.437990
# 848          75.0    45600  213.541565  138.541565
# 53           68.0    50271  224.211953  156.211953
# 661          52.0    46589  215.844852  163.844852
# 769          47.0    53504  231.309317  184.309317
# 451          62.0    70761  266.009398  204.009398
# 313         150.0   215245  463.945040  313.945040

# %%
# closer look at lowest diff
lotdf.head(10)
# Out:
#       LotFrontage  LotArea     ifsqare        diff
# 934         313.0    27650  166.282891 -146.717109
# 1127        182.0    14572  120.714539  -61.285461
# 1298        313.0    63887  252.758778  -60.241222
# 231         174.0    15138  123.036580  -50.963420
# 1211        152.0    12134  110.154437  -41.845563
# 909         149.0    12589  112.200713  -36.799287
# 1182        160.0    15623  124.992000  -35.008000
# 276         129.0     9196   95.895777  -33.104223
# 966         130.0     9600   97.979590  -32.020410
# 429         130.0    11457  107.037377  -22.962623

# %%
###################################################################################################################
### NOTES:
# 
# observation:
#       - variaty of differences too big to make a conclusion via area shape
# decision:
#       - confirm via ols before filling na in wdf with median
#
###################################################################################################################

# %%
# OLS LotArea, LotFrontage

    # add constant
lotdf = sm.add_constant(lotdf)
    
    # ols
results = sm.OLS(lotdf["LotFrontage"], 
                  lotdf[["LotArea", "const"]]).fit()
    # summary
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            LotFrontage   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     233.5
# Date:                Sun, 13 Sep 2020   Prob (F-statistic):           6.43e-48
# Time:                        16:03:49   Log-Likelihood:                -4945.6
# No. Observations:                1094   AIC:                             9895.
# Df Residuals:                    1092   BIC:                             9905.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# LotArea        0.0013    8.2e-05     15.281      0.000       0.001       0.001
# const         58.0678      1.069     54.323      0.000      55.970      60.165
# ==============================================================================
# Omnibus:                      436.477   Durbin-Watson:                   0.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12811.700
# Skew:                           1.214   Prob(JB):                         0.00
# Kurtosis:                      19.588   Cond. No.                     2.07e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
###################################################################################################################
### SUMMARY Frontage/Area:
#
# LotFronatge vals:
#                  - std: 24.508858570320566
#                  - mean: 70.75959780621572
#                  - median: 70.0
#                  - min: 21.0
#                  - max: 313.0
#
# OLS Frontage/Area vals:
#                  - coef: 0.0013
#                  - Adj. R-squared: 0.175
#                  - t: 15.281
#
###################################################################################################################

# %%
###################################################################################################################
### NOTES:
#
# conclusion: OLS confirmed that compared area vals not sufficient to calculate missing frontage vals
#
# decision: missing val will be filled with mean
#
###################################################################################################################

# store mean 
fmean = wdf['LotFrontage'].mean()

# fillna and update
wdf['LotFrontage'] = wdf['LotFrontage'].fillna(fmean)

###################################################################################################################
###################################################################################################################

# %%
###################################################################################################################
# confirm: no more remaining na vals in wdf

confirm = pd.DataFrame(wdf.isna().sum())
len(confirm.loc[confirm[0]>1])==0

###################################################################################################################
# Out:
# True

# %% [markdown]
# # Dtypes

# %%
    # make a temp copy of wdf to be save
temp = wdf.copy()

    # review dtypes and store them to df
temptypes = pd.DataFrame(temp.dtypes)
temptypes = temptypes.loc[temptypes[0]==object]
    # review:
temptypes
# Out:
#                     0
# MSZoning       object
# Street         object
# LotShape       object
# LandContour    object
# Utilities      object
# LotConfig      object
# LandSlope      object
# Neighborhood   object
# Condition1     object
# Condition2     object
# BldgType       object
# HouseStyle     object
# RoofStyle      object
# RoofMatl       object
# Exterior1st    object
# Exterior2nd    object
# MasVnrType     object
# ExterQual      object
# ExterCond      object
# Foundation     object
# BsmtQual       object
# BsmtCond       object
# BsmtExposure   object
# BsmtFinType1   object
# BsmtFinType2   object
# Heating        object
# HeatingQC      object
# CentralAir     object
# Electrical     object
# KitchenQual    object
# Functional     object
# GarageType     object
# GarageFinish   object
# GarageQual     object
# GarageCond     object
# PavedDrive     object
# SaleType       object
# SaleCondition  object

# %%
# save cols to list
listobjcols = temptypes.index.to_list()

# %%
# save len of value counts for object cols
valuecounts = [len(temp[c].value_counts()) for c in listobjcols]

# %%
# v(alue)c(ount) df
data = {'col':listobjcols, 'valcount':valuecounts}
vcdf = pd.DataFrame(data)

# %%
# get binary obj vals and save them to binar
binar = vcdf.loc[vcdf['valcount']==2]
# review
binar
# Out:
#            col  valcount
# 1       Street         2
# 4    Utilities         2
# 27  CentralAir         2

# %%
# get not-binary obj vals and save them to nobinar
nobinar = vcdf.loc[vcdf['valcount']!=2]
# review
nobinar
# Out:
#               col  valcount
# 0        MSZoning         5
# 2        LotShape         4
# 3     LandContour         4
# 5       LotConfig         5
# 6       LandSlope         3
# 7    Neighborhood        25
# 8      Condition1         9
# 9      Condition2         8
# 10       BldgType         5
# 11     HouseStyle         8
# 12      RoofStyle         6
# 13       RoofMatl         8
# 14    Exterior1st        14
# 15    Exterior2nd        16
# 16     MasVnrType         4
# 17      ExterQual         4
# 18      ExterCond         4
# 19     Foundation         5
# 20       BsmtQual         4
# 21       BsmtCond         4
# 22   BsmtExposure         4
# 23   BsmtFinType1         6
# 24   BsmtFinType2         6
# 25        Heating         4
# 26      HeatingQC         5
# 28     Electrical         5
# 29    KitchenQual         4
# 30     Functional         7
# 31     GarageType         6
# 32   GarageFinish         3
# 33     GarageQual         5
# 34     GarageCond         5
# 35     PavedDrive         3
# 36       SaleType         9
# 37  SaleCondition         6

# %%
####################################################################################################################
### NOTES:
# 
# observation: some object values have binary values and can be translated into 0/1 vals
#
# decision: review binary object vals and replace them with numeric vals
#
####################################################################################################################

# %%
####################################################################################################################
# binary object cols:

# storing binar object val cols
binarlist = binar['col'].to_list()
# review
binarlist
# Out:
# ['Street', 'Utilities', 'CentralAir']

# %%
# make a new wdf copy = c(leaned)wdf
cwdf = wdf.copy()

# %%
cwdf["CentralAir"].replace({"Y": 1, "N": 0}, inplace=True)

# %%
cwdf["Utilities"].replace({"AllPub": 1, "NoSeWa": 0}, inplace=True)

# %%
cwdf['Street'].replace({"Pave": 1, "Grvl": 0}, inplace=True)

# %%
####################################################################################################################
# nobinary object cols:
temp = cwdf.copy()

# %%
nobincols = nobinar['col'].to_list()

# %%
#review:
pd.DataFrame([temp[x] for x in nobincols])
# Out:
#                   1404     996      411      1040     370      810      302   \
# MSZoning            RL       RL       RL       RL       RL       RL       RL
# LotShape           Reg      IR1      Reg      Reg      IR1      Reg      IR1
# LandContour        Lvl      Lvl      Bnk      Lvl      Lvl      Lvl      Lvl
# LotConfig       Corner   Inside   Inside   Corner   Inside   Inside   Corner
# LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood   OldTown    NAmes  Gilbert   Sawyer  Gilbert   NWAmes  CollgCr
# Condition1      Artery     Norm     Norm     Norm     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# BldgType             1        1        5        1        1        1        1
# HouseStyle      1.5Fin   1Story   1Story   1Story   2Story   1Story   1Story
# RoofStyle        Gable      Hip      Hip    Gable    Gable      Hip    Gable
# RoofMatl       CompShg  CompShg  CompShg  CompShg  CompShg  CompShg  CompShg
# Exterior1st    Wd Sdng  Wd Sdng  Wd Sdng  Wd Sdng  VinylSd  HdBoard  VinylSd
# Exterior2nd    Wd Sdng  Wd Sdng  Wd Sdng  Wd Sdng  VinylSd  HdBoard  VinylSd
# MasVnrType        None     None     None   BrkCmn     None  BrkFace  BrkFace
# ExterQual           TA       TA       TA       TA       TA       TA       Gd
# ExterCond           TA       TA       TA       TA       TA       TA       TA
# Foundation       PConc   CBlock   CBlock   CBlock    PConc   CBlock    PConc
# BsmtQual            TA       TA       TA       TA       Gd       TA       Gd
# BsmtCond            TA       TA       TA       TA       TA       TA       TA
# BsmtExposure        No       No       Mn       No       No       No       No
# BsmtFinType1       Unf      Rec      Rec      Rec      Unf      ALQ      Unf
# BsmtFinType2       Unf      Unf      Unf      BLQ      Unf      LwQ      Unf
# Heating           GasA     GasA     GasA     GasA     GasA     GasA     GasA
# HeatingQC           TA       TA       TA       Ex       Ex       Fa       Ex
# Electrical       SBrkr    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr    SBrkr
# KitchenQual         TA       TA       TA       TA       TA       Gd       Gd
# Functional         Typ      Typ      Typ     Maj1      Typ      Typ      Typ
# GarageType      Detchd   Attchd   Attchd   Attchd   Attchd   Attchd   Attchd
# GarageFinish       Unf      Unf      Fin      RFn      RFn      RFn      RFn
# GarageQual          TA       TA       TA       TA       TA       TA       TA
# GarageCond          TA       TA       TA       TA       TA       TA       TA
# PavedDrive           Y        Y        Y        Y        Y        Y        Y
# SaleType            WD      COD       WD       WD       WD       WD       WD
# SaleCondition   Family   Normal   Normal   Normal   Normal   Normal   Normal
#
#                   169      141      664   ...     869      324      939   \
# MSZoning            RL       RL       RL  ...       RL       RL       RL
# LotShape           IR1      Reg      IR2  ...      Reg      Reg      Reg
# LandContour        Lvl      Lvl      Lvl  ...      Lvl      Lvl      Lvl
# LotConfig       Corner   Inside  CulDSac  ...   Inside   Corner   Inside
# LandSlope          Gtl      Gtl      Gtl  ...      Gtl      Gtl      Gtl
# Neighborhood    Timber  CollgCr  Somerst  ...  SawyerW    NAmes  ClearCr
# Condition1        Norm     Norm     RRAn  ...     Norm     PosN     Norm
# Condition2        Norm     Norm     Norm  ...     Norm     Norm     Norm
# BldgType             1        1        1  ...        1        1        1
# HouseStyle      1Story   1Story   1Story  ...   2Story     SLvl   2Story
# RoofStyle          Hip    Gable    Gable  ...    Gable  Mansard    Gable
# RoofMatl       WdShake  CompShg  CompShg  ...  CompShg  WdShake  CompShg
# Exterior1st    Plywood  VinylSd  VinylSd  ...  MetalSd  Wd Sdng  MetalSd
# Exterior2nd    Plywood  VinylSd  VinylSd  ...  MetalSd  Wd Sdng  MetalSd
# MasVnrType     BrkFace     None     None  ...  BrkFace  BrkFace     None
# ExterQual           Gd       Gd       Gd  ...       Gd       Gd       TA
# ExterCond           TA       TA       TA  ...       TA       Gd       Gd
# Foundation      CBlock    PConc    PConc  ...    PConc   CBlock   CBlock
# BsmtQual            Gd       Gd       Ex  ...       Gd       Gd       TA
# BsmtCond            TA       TA       TA  ...       TA       TA       TA
# BsmtExposure        No       Av       Mn  ...       No       No       Mn
# BsmtFinType1       Unf      GLQ      GLQ  ...      GLQ      Unf      Unf
# BsmtFinType2       Unf      Unf      Unf  ...      Unf      Unf      Unf
# Heating           GasA     GasA     GasA  ...     GasA     GasA     GasA
# HeatingQC           TA       Ex       Ex  ...       Ex       Ex       Ex
# Electrical       SBrkr    SBrkr    SBrkr  ...    SBrkr    SBrkr    SBrkr
# KitchenQual         TA       Gd       Ex  ...       Gd       Gd       TA
# Functional         Typ      Typ      Typ  ...      Typ      Typ      Typ
# GarageType      Attchd   Attchd   Attchd  ...   Attchd  BuiltIn   Attchd
# GarageFinish       RFn      Fin      Fin  ...      Fin      Fin      Unf
# GarageQual          TA       TA       TA  ...       TA       TA       TA
# GarageCond          TA       TA       TA  ...       TA       TA       TA
# PavedDrive           Y        Y        Y  ...        Y        Y        Y
# SaleType            WD       WD      New  ...       WD       WD      COD
# SaleCondition   Normal   Normal  Partial  ...   Normal   Normal   Normal
#
#                   378      769      1144     1421     419      1160     66
# MSZoning            RL       RL       RL       RL       RL       RL       RL
# LotShape           Reg      IR2      Reg      Reg      Reg      Reg      Reg
# LandContour        Lvl      HLS      Lvl      Lvl      Lvl      Lvl      Lvl
# LotConfig       Corner  CulDSac   Inside   Inside   Inside   Inside   Inside
# LandSlope          Gtl      Mod      Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood   StoneBr  StoneBr  Edwards  NPkVill    NAmes  NPkVill    NAmes
# Condition1        Norm     Norm     Norm     Norm     Norm     Norm     PosA
# Condition2        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# BldgType             1        1        5        2        1        3        1
# HouseStyle      1Story   2Story   1.5Fin   1Story   1Story   2Story   1Story
# RoofStyle          Hip      Hip    Gable    Gable    Gable    Gable    Gable
# RoofMatl       CompShg  CompShg  CompShg  CompShg  CompShg  CompShg  CompShg
# Exterior1st    VinylSd  CemntBd  MetalSd  Plywood  VinylSd  Plywood  Plywood
# Exterior2nd    VinylSd  Wd Shng  MetalSd  Plywood  VinylSd  Brk Cmn  Plywood
# MasVnrType       Stone  BrkFace     None     None     None     None  BrkFace
# ExterQual           Gd       Ex       TA       TA       TA       TA       TA
# ExterCond           TA       TA       Fa       TA       TA       TA       TA
# Foundation       PConc    PConc   BrkTil   CBlock   CBlock   CBlock   CBlock
# BsmtQual            Ex       Gd       Gd       Gd       TA       Gd       Gd
# BsmtCond            TA       TA       TA       TA       TA       TA       TA
# BsmtExposure        Av       Gd       No       No       No       No       Gd
# BsmtFinType1       GLQ      ALQ      BLQ      ALQ      BLQ      ALQ      GLQ
# BsmtFinType2       Unf      Unf      Unf      Unf      Unf      Unf      Unf
# Heating           GasA     GasA     Grav     GasA     GasA     GasA     GasA
# HeatingQC           Ex       Ex       Fa       TA       Ex       Fa       TA
# Electrical       SBrkr    SBrkr    FuseA    SBrkr    SBrkr    SBrkr    SBrkr
# KitchenQual         Ex       Ex       Fa       TA       TA       TA       TA
# Functional         Typ      Mod      Typ      Typ      Typ      Typ     Min1
# GarageType      Attchd  BuiltIn   Detchd   Attchd   Attchd   Attchd   Attchd
# GarageFinish       Fin      Fin      Unf      RFn      Unf      Unf      RFn
# GarageQual          TA       TA       TA       TA       TA       TA       TA
# GarageCond          TA       TA       TA       TA       TA       TA       TA
# PavedDrive           Y        Y        Y        Y        Y        Y        Y
# SaleType           New       WD       WD       WD       WD       WD       WD
# SaleCondition  Partial   Normal   Normal   Normal   Normal   Normal   Normal
#
# [35 rows x 1338 columns]

# %%
def replacer(col):
    coldf = pd.DataFrame(temp[col].value_counts()).reset_index().rename(columns={'index':'oldval'}).reset_index()
    coldf['rank'] = coldf['index']+1
    newvals = coldf['rank'].to_list()
    oldvals = coldf['oldval'].to_list()
    dictreplace = dict(zip(oldv,newv))
    return dictreplace

# %%
replacerlist = []

for col in nobincols:
    c = str(col)
    d = replacer(col)
    replacerlist.append(d)

# %%
# do through val replacements manually and print each vals to check

# copy cwdf to ccdf:
ccdf = cwdf.copy()

# %%
i = 0
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 1 MSZoning {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 2 LotShape {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 3 LandContour {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 4 LotConfig {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 5 LandSlope {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 6 Neighborhood {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 7 Condition1 {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 8 Condition2 {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
# val error for i=9

col = 'HouseStyle'
ndf = pd.DataFrame(ccdf[col].value_counts()).reset_index().reset_index().rename(columns={'index':'col'})
ndf['rank'] = ndf['level_0']+1
oldv = ndf['col'].to_list()
nval = ndf['rank'].to_list()
d = dict(zip(oldv,nval))
ccdf[col] = ccdf[col].replace(d)

# %%
# continue with i = 10

i = 10
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 11 RoofStyle {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 12 RoofMatl {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 13 Exterior1st {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 14 Exterior2nd {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 15 MasVnrType {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 16 ExterQual {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 17 ExterCond {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 18 Foundation {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 19 BsmtQual {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 20 BsmtCond {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 21 BsmtExposure {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 22 BsmtFinType1 {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 23 BsmtFinType2 {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 24 Heating {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 25 HeatingQC {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 26 Electrical {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 27 KitchenQual {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 28 Functional {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 29 GarageType {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 30 GarageFinish {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 31 GarageQual {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
c = nobincols[i] 
d = replacerlist[i]
ccdf[c] = ccdf[c].replace(d)
i +=1
print(i,c,d)
# Out:
# 32 GarageCond {'1Fam': 1, 'TwnhsE': 2, 'Twnhs': 3, 'Duplex': 4, '2fmCon': 5}

# %%
# copy ccdf to findf

cleandf = ccdf.copy()

####################################################################################################################

# %%
####################################################################################################################
####################################################################################################################
### EXPORT:
#
# cleandf to csv

cleandf.to_csv('cleandata.csv')

####################################################################################################################
####################################################################################################################
